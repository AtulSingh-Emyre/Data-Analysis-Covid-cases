# %% [markdown]
# # Collection of data

# %%
# Import necessary libraries
import numpy as np
import pandas as pd
from datetime import date
# %matplotlib inline
import matplotlib as mpl
import matplotlib.pyplot as plt
import matplotlib.patches as mpatches
import seaborn as sns
import os # to work with local directory
import re
import wptools
import json # to create json file from python dictionary
import time # for timer 
sns.set()
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-3-44ece239e75c> in <module>
#      10 import os # to work with local directory
#      11 import re
# ---> 12 import wptools
#      13 import json # to create json file from python dictionary
#      14 import time # for timer
#
# ModuleNotFoundError: No module named 'wptools'

# %%
# Install a pip package in the current Jupyter kernel
import sys
# !{sys.executable} -m pip install wptools
# Out:
# Collecting wptools
#   Downloading wptools-0.4.17-py2.py3-none-any.whl (38 kB)
# Requirement already satisfied: certifi in c:\users\ati\appdata\local\programs\python\python38\lib\site-packages (from wptools) (2020.6.20)
# Collecting html2text
#   Downloading html2text-2020.1.16-py3-none-any.whl (32 kB)
# Collecting lxml
#   Downloading lxml-4.6.2-cp38-cp38-win_amd64.whl (3.5 MB)
# Collecting pycurl
#   Downloading pycurl-7.43.0.6.tar.gz (222 kB)
#     ERROR: Command errored out with exit status 10:
#      command: 'c:\users\ati\appdata\local\programs\python\python38\python.exe' -c 'import sys, setuptools, tokenize; sys.argv[0] = '"'"'C:\\Users\\Ati\\AppData\\Local\\Temp\\pip-install-a6f81smo\\pycurl_edd4bdc937ca4d70acf57dfaedaa3b8b\\setup.py'"'"'; __file__='"'"'C:\\Users\\Ati\\AppData\\Local\\Temp\\pip-install-a6f81smo\\pycurl_edd4bdc937ca4d70acf57dfaedaa3b8b\\setup.py'"'"';f=getattr(tokenize, '"'"'open'"'"', open)(__file__);code=f.read().replace('"'"'\r\n'"'"', '"'"'\n'"'"');f.close();exec(compile(code, __file__, '"'"'exec'"'"'))' egg_info --egg-base 'C:\Users\Ati\AppData\Local\Temp\pip-pip-egg-info-ppm80khd'
#          cwd: C:\Users\Ati\AppData\Local\Temp\pip-install-a6f81smo\pycurl_edd4bdc937ca4d70acf57dfaedaa3b8b\
#     Complete output (1 lines):
#     Please specify --curl-dir=/path/to/built/libcurl
#     ----------------------------------------
# ERROR: Command errored out with exit status 10: python setup.py egg_info Check the logs for full command output.

# %%
# Gather data from John Hopkins GitHub 
df_JHU_Fatality = pd.read_csv('https://raw.githubusercontent.com/CSSEGISandData/COVID-19/master/csse_covid_19_data/csse_covid_19_time_series/time_series_covid19_deaths_global.csv')
df_JHU_Confirmed = pd.read_csv('https://raw.githubusercontent.com/CSSEGISandData/COVID-19/master/csse_covid_19_data/csse_covid_19_time_series/time_series_covid19_confirmed_global.csv')
df_JHU_Recovered = pd.read_csv('https://raw.githubusercontent.com/CSSEGISandData/COVID-19/master/csse_covid_19_data/csse_covid_19_time_series/time_series_covid19_recovered_global.csv')
df_JHU_Countries = pd.read_csv('https://raw.githubusercontent.com/RRighart/covid-19/master/countries.csv')

# %%
df_JHU_Fatality.sample(n=5)
# Out:
#     Province/State       Country/Region      Lat      Long  1/22/20  1/23/20  \
# 5              NaN  Antigua and Barbuda  17.0608  -61.7964        0        0
# 29             NaN             Botswana -22.3285   24.6849        0        0
# 11      Queensland            Australia -27.4698  153.0251        0        0
# 69           Henan                China  37.8957  114.9042        0        0
# 209            NaN                Qatar  25.3548   51.1839        0        0
#
#      1/24/20  1/25/20  1/26/20  1/27/20  ...  11/22/20  11/23/20  11/24/20  \
# 5          0        0        0        0  ...         4         4         4
# 29         0        0        0        0  ...        31        31        31
# 11         0        0        0        0  ...         6         6         6
# 69         0        0        1        1  ...        22        22        22
# 209        0        0        0        0  ...       236       236       236
#
#      11/25/20  11/26/20  11/27/20  11/28/20  11/29/20  11/30/20  12/1/20
# 5           4         4         4         4         4         4        4
# 29         31        31        31        31        31        34       34
# 11          6         6         6         6         6         6        6
# 69         22        22        22        22        22        22       22
# 209       237       237       237       237       237       237      238
#
# [5 rows x 319 columns]
